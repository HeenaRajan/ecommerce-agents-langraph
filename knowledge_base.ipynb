# %%
import pandas as pd
import tqdm
import time
import pickle
import ast
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableMap
from langchain_openai import ChatOpenAI
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine
import json

# %%
table_description = {

'customer' : '''Contains customer information.
Columns:
- customer_id: unique identifier for each customer
- customer_unique_id: another unique identifier for each customer
- customer_zip_code_prefix: postal code prefix of the customer
- customer_city: city of the customer
- customer_state: state of the customer''',

'orders'  : '''Contains order information.
Columns:
- order_id: unique identifier for each order
- order_item_id: sequential number of items in the order
- product_id: foreign key referencing products.product_id
- seller_id: foreign key referencing sellers.seller_id
- shipping_limit_date: latest date the seller can hand over the item to the logistics partner
- price: price of the item in the order
- freight_value: freight cost for the item in the order''',

'order_items'  : '''Contains item-level information for each order.
Columns:
- order_id: foreign key referencing orders.order_id
- order_item_id: sequential number of the item in the order
- product_id: foreign key referencing products.product_id
- seller_id: foreign key referencing sellers.seller_id
- shipping_limit_date: latest date for the seller to hand over the item to logistics
- price: price of the item
- freight_value: freight cost of the item''',

'order_payments'  : '''Contains payment details for each order.
Columns:
- order_id: foreign key referencing orders.order_id
- payment_sequential: sequence number of the payment for an order, used if the customer pays with multiple methods
- payment_type: method of payment used
- payment_installments: number of installments chosen for this payment
- payment_value: value of this specific payment transaction''',

'order_reviews'  : '''Contains customer reviews of orders.
Columns:
- review_id: unique identifier for each review
- order_id: foreign key referencing orders.order_id
- review_score: numeric score given by the customer
- review_comment_title: short title or summary of the review provided by the customer
- review_comment_message: full text comment provided by the customer
- review_creation_date: date when the review was submitted by the customer
- review_answer_timestamp: date when the seller or platform responded to the review (if any)''',

'products'  : '''Contains product information.
Columns:
- product_id: unique identifier for each product
- product_category_name: category of the product in Brazilian Portuguese
- product_name_lenght: length of the product name in characters
- product_description_lenght: length of the product description in characters
- product_photos_qty: number of photos available for the product
- product_weight_g: weight of the product in grams
- product_length_cm: product length in centimeters
- product_height_cm: product height in centimeters
- product_width_cm: product width in centimeters''',

'product_category_translation' : '''Maps product categories from Brazilian Portuguese to English.
Columns:
- product_category_name: category name in Portuguese
- product_category_name_english: translated category name''',

'sellers'  : '''Contains seller information.
Columns:
- seller_id: unique identifier for each seller
- seller_zip_code_prefix: postal code prefix of the seller's location
- seller_city: city of the seller
- seller_state: state of the seller''',

}

# %%
# Load environment variables from .env file
load_dotenv()

# Read credentials from environment variables
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
database = os.getenv("DB_NAME")

# Create SQLAlchemy engine
engine = create_engine(
    f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}"
)

try:
    with engine.connect() as conn:
        print("MySQL connection successful!")
except Exception as e:
    print("Connection failed:", e)


def read_sql_sample(table, n=5):
    """
    Returns:
    - df_sample: Pandas DataFrame with n random rows
    - sample_json: list of dicts (JSON style)
    - column_types: dict {column_name: datatype}
    """
    query = f"SELECT * FROM {table} ORDER BY RAND() LIMIT {n};"
    df_sample = pd.read_sql(query, con=engine)

    sample_json = df_sample.to_dict(orient='records')
    column_types = {col: str(dtype) for col, dtype in zip(df_sample.columns, df_sample.dtypes)}

    return df_sample, sample_json, column_types
# Out:
# MySQL connection successful!

# %%
model = ChatOpenAI(
    model="gpt-5.2",
    temperature=0.2,
    max_tokens=1000,
    timeout=30
)

template = ChatPromptTemplate.from_messages([
("system", """
You are an intelligent data annotator. Annotate SQL tables with detailed column-level descriptions.
Use the sample data and column types provided to generate JSON output.
Do not invent columns. Use exact column names.
Output must be valid JSON in the following format:

{{
  "table_description": "<table description>",
  "columns": [
    {{
      "column_name": "<column name>",
      "description": "<detailed description>",
      "datatype": "<datatype>",
      "sample_values": ["v1", "v2"]
    }}
  ]
}}

Always include 1-2 sample values per column.
Do not add any extra text.
"""),
("human", """
SQL table description:
{description}

Sample rows from the table:
{data_sample}

Column data types:
{column_types}
""")
])


# chain = (
#     RunnableMap({
#         "description": lambda x: x["description"],
#         "data_sample": lambda x: x["data_sample"],
#         "column_types": lambda x: x["column_types"]
#     })
#     | template
#     | model
#     | StrOutputParser()
# )

chain = template | model | StrOutputParser()

# %%
kb_final = {}

for table_name, description in tqdm.tqdm(table_description.items()):
    df, sample_json, column_types = read_sql_sample(table_name, n=5)

    # Convert to JSON string for LLM
    sample_str = json.dumps(sample_json[:2], ensure_ascii=False)  # only 1-2 rows
    types_str = json.dumps(column_types, ensure_ascii=False)

    response = chain.invoke({
        "description": description,
        "data_sample": sample_str,
        "column_types": types_str
    }).replace('```', '')

    try:
        kb_final[table_name] = json.loads(response)
    except json.JSONDecodeError:
        print(f"JSON parse error for table: {table_name}")
        print("LLM response:", response)
        kb_final[table_name] = None
# Out:
# 100%|█████████████████████████████████████████████| 8/8 [01:13<00:00,  9.17s/it]

# %%
kb_final
# Out:
# {'customer': {'table_description': 'Stores customer location and identifier information, including customer IDs, postal code prefix, city, and state for each customer record.',
#   'columns': [{'column_name': 'customer_id',
#     'description': 'Primary unique identifier for a customer record in the dataset; typically a system-generated alphanumeric hash used to reference the customer in related tables (e.g., orders).',
#     'datatype': 'object',
#     'sample_values': ['60c9c9568fdcbbccfc7ddc387f76e200',
#      '8877f3c1264d413a5033eca3d7510da2']},
#    {'column_name': 'customer_unique_id',
#     'description': 'Secondary unique identifier representing the underlying customer identity; may link multiple customer records that belong to the same person across different transactions or registrations.',
#     'datatype': 'object',
#     'sample_values': ['5cdbff27ae9bb0812d23e36f517feb23',
#      '1c78cc523e89a9c1d0beef9598566562']},
#    {'column_name': 'customer_zip_code_prefix',
#     'description': "Numeric prefix of the customer's postal (ZIP) code used for coarse geographic grouping and regional analysis; not necessarily the full ZIP code.",
#     'datatype': 'int64',
#     'sample_values': ['29208', '24220']},
#    {'column_name': 'customer_city',
#     'description': "City name associated with the customer's address/location, typically in lowercase as stored in the source data.",
#     'datatype': 'object',
#     'sample_values': ['guarapari', 'niteroi']},
#    {'column_name': 'customer_state',
#     'description': "Two-letter state abbreviation indicating the customer's state/region (e.g., Brazilian federative units).",
#     'datatype': 'object',
#     'sample_values': ['ES', 'RJ']}]},
#  'orders': {'table_description': 'Line-item level order details capturing each product sold within an order, including the seller responsible, shipping handover deadline, item price, and freight cost.',
#   'columns': [{'column_name': 'order_id',
#     'description': 'Unique identifier of the order that this line item belongs to; used to group multiple items purchased in the same checkout/order.',
#     'datatype': 'object',
#     'sample_values': ['43792e0661fefd6aa82a64f601325ddb',
#      '9aea5beb82a36ec0003d98ea8d832e2a']},
#    {'column_name': 'order_item_id',
#     'description': 'Sequential line-item number within the order (e.g., 1 for the first item in the order), distinguishing multiple items under the same order_id.',
#     'datatype': 'int64',
#     'sample_values': ['1', '1']},
#    {'column_name': 'product_id',
#     'description': 'Foreign key referencing the product sold in this order line item (links to products.product_id).',
#     'datatype': 'object',
#     'sample_values': ['2028bf1b01cafb2d2b1901fca4083222',
#      'c10a7001e8b49dfc03817444b5f2ed81']},
#    {'column_name': 'seller_id',
#     'description': 'Foreign key identifying the seller fulfilling this item (links to sellers.seller_id); indicates which merchant is responsible for shipping the product.',
#     'datatype': 'object',
#     'sample_values': ['cc419e0650a3c5ba77189a1882b7556a',
#      '056b4ada5bbc2c50cc7842547dda6b51']},
#    {'column_name': 'shipping_limit_date',
#     'description': 'Deadline timestamp by which the seller must hand over the item to the logistics/shipping partner; used for SLA and late-shipment analysis.',
#     'datatype': 'object',
#     'sample_values': ['2018-01-08 12:31:37', '2018-07-04 18:55:13']},
#    {'column_name': 'price',
#     'description': 'Unit price charged for the product in this order line item, excluding freight/shipping charges.',
#     'datatype': 'float64',
#     'sample_values': ['56.99', '129.99']},
#    {'column_name': 'freight_value',
#     'description': 'Freight/shipping cost allocated to this order line item; typically added on top of the item price for total cost calculations.',
#     'datatype': 'float64',
#     'sample_values': ['25.68', '9.25']}]},
#  'order_items': {'table_description': 'Contains item-level line details for each order, including the product and seller involved, the shipping handoff deadline, and item-level pricing and freight costs.',
#   'columns': [{'column_name': 'order_id',
#     'description': 'Unique identifier of the order this line item belongs to; foreign key referencing orders.order_id. Multiple rows can share the same order_id when an order contains multiple items.',
#     'datatype': 'object',
#     'sample_values': ['b41f51ebf23530b00f69e5602f81a653',
#      '90a6c3a55e9c9cf3db4bd490b9ab44c7']},
#    {'column_name': 'order_item_id',
#     'description': 'Sequential line number of the item within the order (e.g., 1 for the first item). Typically unique only in combination with order_id.',
#     'datatype': 'int64',
#     'sample_values': [1, 1]},
#    {'column_name': 'product_id',
#     'description': 'Unique identifier of the product purchased in this order line; foreign key referencing products.product_id.',
#     'datatype': 'object',
#     'sample_values': ['b38b25d838ae0b8385e8cc68b9017644',
#      '5d10b3779b68d58be0fcc46a1ee79689']},
#    {'column_name': 'seller_id',
#     'description': 'Unique identifier of the seller fulfilling this specific order item; foreign key referencing sellers.seller_id.',
#     'datatype': 'object',
#     'sample_values': ['fad44952713764836814be105382aee5',
#      '4559697a8f7e637227c2eeaed843baff']},
#    {'column_name': 'shipping_limit_date',
#     'description': 'Deadline timestamp by which the seller must hand over the item to the logistics carrier for shipping, typically used to measure fulfillment timeliness.',
#     'datatype': 'object',
#     'sample_values': ['2018-02-19 00:35:33', '2018-03-22 17:31:50']},
#    {'column_name': 'price',
#     'description': 'Unit sale price charged for this item line (excluding freight). Expressed as a decimal monetary amount.',
#     'datatype': 'float64',
#     'sample_values': [180.0, 169.9]},
#    {'column_name': 'freight_value',
#     'description': 'Freight/shipping cost allocated to this item line, expressed as a decimal monetary amount.',
#     'datatype': 'float64',
#     'sample_values': [15.01, 14.55]}]},
#  'order_payments': {'table_description': 'Contains payment transaction details for each order, including payment method, sequencing for multi-method payments, installment count, and the monetary value of each payment record.',
#   'columns': [{'column_name': 'order_id',
#     'description': 'Unique identifier of the order this payment record belongs to; acts as a foreign key referencing orders.order_id and groups all payment entries for the same order.',
#     'datatype': 'object',
#     'sample_values': ['9c9caabac80e005ba36cb7c06afc0fe3',
#      '003d804eef0e1b856881cd18e0cc0d4c']},
#    {'column_name': 'payment_sequential',
#     'description': 'Sequence number of the payment entry within a single order (e.g., 1 for the first payment record, 2 for an additional payment method/attempt), used to order multiple payment records tied to the same order.',
#     'datatype': 'int64',
#     'sample_values': ['1', '1']},
#    {'column_name': 'payment_type',
#     'description': 'Payment method used for this specific payment record (e.g., bank slip/boleto, credit card), indicating how the customer paid for the order or part of the order.',
#     'datatype': 'object',
#     'sample_values': ['boleto', 'credit_card']},
#    {'column_name': 'payment_installments',
#     'description': 'Number of installments selected for this payment record; typically 1 for single-payment methods and greater than 1 for installment-based card payments.',
#     'datatype': 'int64',
#     'sample_values': ['1', '3']},
#    {'column_name': 'payment_value',
#     'description': 'Monetary amount charged in this specific payment transaction/record for the order; represents the value associated with the given payment method and sequence entry.',
#     'datatype': 'float64',
#     'sample_values': ['168.23', '312.74']}]},
#  'order_reviews': {'table_description': 'Contains customer-submitted reviews for completed orders, including rating score, optional written feedback, and timestamps for when the review was created and when (if applicable) it received a response from the seller or platform.',
#   'columns': [{'column_name': 'review_id',
#     'description': 'Unique identifier for each customer review record (typically a hashed/string ID) used to distinguish one review from another in the dataset.',
#     'datatype': 'object',
#     'sample_values': ['a1cff3be05c0d28caa9e8b55dbeb0a70',
#      'e6cd89f319b7c69b9b4c6babc632db08']},
#    {'column_name': 'order_id',
#     'description': 'Identifier of the order being reviewed; acts as a foreign key to the orders table (orders.order_id) to link review details back to the corresponding purchase.',
#     'datatype': 'object',
#     'sample_values': ['fabf6de4b124e6dda46615c09ecd7476',
#      'df91fb38017b42722551a94382cb829a']},
#    {'column_name': 'review_score',
#     'description': 'Numeric rating assigned by the customer to the order, representing satisfaction level (commonly on a 1–5 scale where higher is better).',
#     'datatype': 'int64',
#     'sample_values': ['5', '5']},
#    {'column_name': 'review_comment_title',
#     'description': "Optional short title or summary of the customer's review; may be null when the customer provides no title.",
#     'datatype': 'object',
#     'sample_values': [None, None]},
#    {'column_name': 'review_comment_message',
#     'description': "Optional free-text message containing the customer's detailed feedback about the product/order experience; may be null when no written comment is provided.",
#     'datatype': 'object',
#     'sample_values': ['produto bom,entrega no tempo previsto, recomendo.',
#      None]},
#    {'column_name': 'review_creation_date',
#     'description': 'Timestamp (stored as a string/object) indicating when the customer submitted/created the review.',
#     'datatype': 'object',
#     'sample_values': ['2017-11-15 00:00:00', '2018-05-04 00:00:00']},
#    {'column_name': 'review_answer_timestamp',
#     'description': 'Timestamp (stored as a string/object) indicating when the seller or platform responded to the review; may be null if no response was made.',
#     'datatype': 'object',
#     'sample_values': ['2017-11-18 10:45:30', '2018-05-05 22:45:43']}]},
#  'products': {'table_description': 'Contains product-level attributes including category (in Brazilian Portuguese), text length metadata, photo availability, and physical dimensions/weight for each product.',
#   'columns': [{'column_name': 'product_id',
#     'description': 'Unique identifier for each product record, typically represented as a hashed alphanumeric string used to join with other product-related tables.',
#     'datatype': 'object',
#     'sample_values': ['25d22295e68fa5bc9fff2b947a3eaeb5',
#      '5b0b1b9c6b42c532349cfa6d0d5bfa58']},
#    {'column_name': 'product_category_name',
#     'description': 'Product category label in Brazilian Portuguese (snake_case), indicating the main classification of the product.',
#     'datatype': 'object',
#     'sample_values': ['malas_acessorios', 'beleza_saude']},
#    {'column_name': 'product_name_lenght',
#     'description': 'Length of the product name text, measured in number of characters (stored as a numeric value).',
#     'datatype': 'float64',
#     'sample_values': [54.0, 53.0]},
#    {'column_name': 'product_description_lenght',
#     'description': 'Length of the product description text, measured in number of characters (stored as a numeric value).',
#     'datatype': 'float64',
#     'sample_values': [348.0, 871.0]},
#    {'column_name': 'product_photos_qty',
#     'description': 'Number of photos available/registered for the product listing (stored as a numeric value).',
#     'datatype': 'float64',
#     'sample_values': [1.0, 1.0]},
#    {'column_name': 'product_weight_g',
#     'description': 'Product weight in grams, used for shipping/logistics calculations (stored as a numeric value).',
#     'datatype': 'float64',
#     'sample_values': [1600.0, 1550.0]},
#    {'column_name': 'product_length_cm',
#     'description': 'Product package length in centimeters, representing the longest dimension used in freight/shipping calculations (stored as a numeric value).',
#     'datatype': 'float64',
#     'sample_values': [41.0, 25.0]},
#    {'column_name': 'product_height_cm',
#     'description': 'Product package height in centimeters, used along with other dimensions for volumetric weight and shipping estimates (stored as a numeric value).',
#     'datatype': 'float64',
#     'sample_values': [15.0, 23.0]},
#    {'column_name': 'product_width_cm',
#     'description': 'Product package width in centimeters, used with length and height to compute package volume for logistics (stored as a numeric value).',
#     'datatype': 'float64',
#     'sample_values': [29.0, 23.0]}]},
#  'product_category_translation': {'table_description': 'Maps product category names from Brazilian Portuguese to their corresponding English translations, enabling consistent category labeling across languages.',
#   'columns': [{'column_name': 'product_category_name',
#     'description': 'Product category identifier/name written in Brazilian Portuguese, typically formatted in lowercase with words separated by underscores; used as the source category label to be translated.',
#     'datatype': 'object',
#     'sample_values': ['sinalizacao_e_seguranca', 'livros_importados']},
#    {'column_name': 'product_category_name_english',
#     'description': 'English translation of the Brazilian Portuguese product category name, typically formatted in lowercase with underscores; used as the standardized English category label corresponding to product_category_name.',
#     'datatype': 'object',
#     'sample_values': ['signaling_and_security', 'books_imported']}]},
#  'sellers': {'table_description': "Stores seller location and identification details, including a unique seller ID and the seller's address location components (ZIP code prefix, city, and state).",
#   'columns': [{'column_name': 'seller_id',
#     'description': 'Unique identifier for each seller record, represented as a fixed-length alphanumeric string (commonly a hash-like ID) used to join seller data to other commerce entities such as orders or products.',
#     'datatype': 'object',
#     'sample_values': ['9b1f656ca3060f8af17a50d8a024b533',
#      'b76a1f8356322f12529c37b67d5c96c2']},
#    {'column_name': 'seller_zip_code_prefix',
#     'description': "Numeric prefix of the seller's postal (ZIP) code used for approximate geographic grouping (e.g., first digits of a full postal code) rather than a complete street-level ZIP code.",
#     'datatype': 'int64',
#     'sample_values': ['11013', '11015']},
#    {'column_name': 'seller_city',
#     'description': 'City name where the seller is located, stored in lowercase text and used for regional analysis and location-based aggregations.',
#     'datatype': 'object',
#     'sample_values': ['santos', 'santos']},
#    {'column_name': 'seller_state',
#     'description': "Two-letter state abbreviation indicating the seller's state/region (e.g., Brazilian federative unit code) for higher-level geographic categorization.",
#     'datatype': 'object',
#     'sample_values': ['SP', 'SP']}]}}

# %%
with open('kb.pkl', 'wb') as f:
    pickle.dump(kb_final, f)
