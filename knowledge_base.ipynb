# %%
import pandas as pd
import tqdm
import time
import pickle
import ast
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableMap
from langchain_openai import ChatOpenAI
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine
import json

# %%
table_description = {

'customer' : '''Contains customer information.
Columns:
- customer_id: unique identifier for each customer
- customer_unique_id: another unique identifier for each customer
- customer_zip_code_prefix: postal code prefix of the customer
- customer_city: city of the customer
- customer_state: state of the customer''',

'orders'  : '''Contains order information.
Columns:
- order_id: unique identifier for each order
- order_item_id: sequential number of items in the order
- product_id: foreign key referencing products.product_id
- seller_id: foreign key referencing sellers.seller_id
- shipping_limit_date: latest date the seller can hand over the item to the logistics partner
- price: price of the item in the order
- freight_value: freight cost for the item in the order''',

'order_items'  : '''Contains item-level information for each order.
Columns:
- order_id: foreign key referencing orders.order_id
- order_item_id: sequential number of the item in the order
- product_id: foreign key referencing products.product_id
- seller_id: foreign key referencing sellers.seller_id
- shipping_limit_date: latest date for the seller to hand over the item to logistics
- price: price of the item
- freight_value: freight cost of the item''',

'order_payments'  : '''Contains payment details for each order.
Columns:
- order_id: foreign key referencing orders.order_id
- payment_sequential: sequence number of the payment for an order, used if the customer pays with multiple methods
- payment_type: method of payment used
- payment_installments: number of installments chosen for this payment
- payment_value: value of this specific payment transaction''',

'order_reviews'  : '''Contains customer reviews of orders.
Columns:
- review_id: unique identifier for each review
- order_id: foreign key referencing orders.order_id
- review_score: numeric score given by the customer
- review_comment_title: short title or summary of the review provided by the customer
- review_comment_message: full text comment provided by the customer
- review_creation_date: date when the review was submitted by the customer
- review_answer_timestamp: date when the seller or platform responded to the review (if any)''',

'products'  : '''Contains product information.
Columns:
- product_id: unique identifier for each product
- product_category_name: category of the product in Brazilian Portuguese
- product_name_lenght: length of the product name in characters
- product_description_lenght: length of the product description in characters
- product_photos_qty: number of photos available for the product
- product_weight_g: weight of the product in grams
- product_length_cm: product length in centimeters
- product_height_cm: product height in centimeters
- product_width_cm: product width in centimeters''',

'product_category_translation' : '''Maps product categories from Brazilian Portuguese to English.
Columns:
- product_category_name: category name in Portuguese
- product_category_name_english: translated category name''',

'sellers'  : '''Contains seller information.
Columns:
- seller_id: unique identifier for each seller
- seller_zip_code_prefix: postal code prefix of the seller's location
- seller_city: city of the seller
- seller_state: state of the seller''',

}

# %%
# Load environment variables from .env file
load_dotenv()

# Read credentials from environment variables
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
database = os.getenv("DB_NAME")

# Create SQLAlchemy engine
engine = create_engine(
    f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}"
)

try:
    with engine.connect() as conn:
        print("MySQL connection successful!")
except Exception as e:
    print("Connection failed:", e)


def read_sql_sample(table, n=5):
    """
    Returns:
    - df_sample: Pandas DataFrame with n random rows
    - sample_json: list of dicts (JSON style)
    - column_types: dict {column_name: datatype}
    """
    query = f"SELECT * FROM {table} ORDER BY RAND() LIMIT {n};"
    df_sample = pd.read_sql(query, con=engine)

    sample_json = df_sample.to_dict(orient='records')
    column_types = {col: str(dtype) for col, dtype in zip(df_sample.columns, df_sample.dtypes)}

    return df_sample, sample_json, column_types
# Out:
# MySQL connection successful!

# %%
model = ChatOpenAI(
    model="gpt-5.2",
    temperature=0.2,
    max_tokens=1000,
    timeout=30
)

template = ChatPromptTemplate.from_messages([
("system", """
You are an intelligent data annotator. Annotate SQL tables with detailed column-level descriptions.
Use the sample data and column types provided to generate JSON output.
Do not invent columns. Use exact column names.
Output must be valid JSON in the following format:

{{
  "table_description": "<table description>",
  "columns": [
    {{
      "column_name": "<column name>",
      "description": "<detailed description>",
      "datatype": "<datatype>",
      "sample_values": ["v1", "v2"]
    }}
  ]
}}

Always include 1-2 sample values per column.
Do not add any extra text.
"""),
("human", """
SQL table description:
{description}

Sample rows from the table:
{data_sample}

Column data types:
{column_types}
""")
])


chain = (
    RunnableMap({
        "description": lambda x: x["description"],
        "data_sample": lambda x: x["data_sample"],
        "column_types": lambda x: x["column_types"]
    })
    | template
    | model
    | StrOutputParser()
)

# %%
kb_final = {}

for table_name, description in tqdm.tqdm(table_description.items()):
    df, sample_json, column_types = read_sql_sample(table_name, n=5)

    # Convert to JSON string for LLM
    sample_str = json.dumps(sample_json[:2], ensure_ascii=False)  # only 1-2 rows
    types_str = json.dumps(column_types, ensure_ascii=False)

    response = chain.invoke({
        "description": description,
        "data_sample": sample_str,
        "column_types": types_str
    }).replace('```', '')

    try:
        kb_final[table_name] = json.loads(response)
    except json.JSONDecodeError:
        print(f"JSON parse error for table: {table_name}")
        print("LLM response:", response)
        kb_final[table_name] = None
# Out:
# 100%|█████████████████████████████████████████████| 8/8 [01:02<00:00,  7.75s/it]

# %%
kb_final
# Out:
# {'customer': {'table_description': 'Contains customer information, including identifiers and location details such as ZIP code prefix, city, and state.',
#   'columns': [{'column_name': 'customer_id',
#     'description': 'Primary customer identifier used to uniquely identify each customer record in the table; typically a hashed or UUID-like string.',
#     'datatype': 'object',
#     'sample_values': ['4a59da975dc45b6c9dd86cec34515ae9',
#      '90d791d06a3613f5232770d70dca4c63']},
#    {'column_name': 'customer_unique_id',
#     'description': 'Alternate unique identifier for a customer, often used to link multiple customer records that may belong to the same underlying person/entity across transactions.',
#     'datatype': 'object',
#     'sample_values': ['e2005120e78d27397fb7f97c83c33426',
#      'cfdf2eeb223da082e4be3c1259830470']},
#    {'column_name': 'customer_zip_code_prefix',
#     'description': "Numeric prefix of the customer's postal (ZIP) code, used for coarse geolocation and regional analysis without storing the full postal code.",
#     'datatype': 'int64',
#     'sample_values': ['15505', '37496']},
#    {'column_name': 'customer_city',
#     'description': "Name of the city associated with the customer's address information.",
#     'datatype': 'object',
#     'sample_values': ['votuporanga', 'turvolandia']},
#    {'column_name': 'customer_state',
#     'description': "Two-letter state abbreviation indicating the customer's state/region.",
#     'datatype': 'object',
#     'sample_values': ['SP', 'MG']}]},
#  'orders': {'table_description': "Contains line-item level order information, linking each order and its individual items to the purchased product, the fulfilling seller, the seller's shipping handover deadline, and the monetary amounts for item price and freight cost.",
#   'columns': [{'column_name': 'order_id',
#     'description': 'Unique identifier for an order. This value groups together one or more order items that belong to the same customer order.',
#     'datatype': 'object',
#     'sample_values': ['e9bfa573b732937bcce0dfee81481cdb',
#      'a38bcbcce65d77a0fc34b3ae0445896e']},
#    {'column_name': 'order_item_id',
#     'description': 'Sequential identifier of the item within the order, used to distinguish multiple products/items under the same order_id (typically starts at 1 and increments per item).',
#     'datatype': 'int64',
#     'sample_values': [1, 1]},
#    {'column_name': 'product_id',
#     'description': 'Foreign key referencing products.product_id, identifying the specific product SKU/item being purchased on this order line.',
#     'datatype': 'object',
#     'sample_values': ['781afe929e3016a667f5f439afd55fce',
#      '5459103ed3b2f852d267e6a70b00dc24']},
#    {'column_name': 'seller_id',
#     'description': 'Foreign key referencing sellers.seller_id, identifying the seller responsible for fulfilling and shipping this specific order item.',
#     'datatype': 'object',
#     'sample_values': ['08633c14ef2db992c11f840f04fad4cd',
#      '76d5af76d0271110f9af36c92573f765']},
#    {'column_name': 'shipping_limit_date',
#     'description': 'Deadline timestamp indicating the latest date/time by which the seller must hand over the order item to the logistics/shipping partner.',
#     'datatype': 'object',
#     'sample_values': ['2018-07-23 17:50:15', '2018-01-09 22:30:22']},
#    {'column_name': 'price',
#     'description': 'Monetary price charged for the item on this order line, excluding freight/shipping charges.',
#     'datatype': 'float64',
#     'sample_values': [107.9, 418.0]},
#    {'column_name': 'freight_value',
#     'description': 'Monetary freight/shipping cost allocated to this order item (the shipping charge for the item within the order).',
#     'datatype': 'float64',
#     'sample_values': [22.69, 92.16]}]},
#  'order_items': {'table_description': "Item-level line items for each customer order, linking orders to products and sellers with pricing, freight charges, and the seller's shipping handover deadline for each item.",
#   'columns': [{'column_name': 'order_id',
#     'description': 'Unique identifier of the order that this line item belongs to; acts as a foreign key to the orders table and groups multiple items under the same purchase.',
#     'datatype': 'object',
#     'sample_values': ['5bec4a58e5df698e8602c589435a8ea5',
#      '424fc0f988d894a7f554fecf40c910d4']},
#    {'column_name': 'order_item_id',
#     'description': 'Sequential line number of the item within a given order_id (e.g., 1 for the first item), used to distinguish multiple items in the same order.',
#     'datatype': 'int64',
#     'sample_values': ['1', '1']},
#    {'column_name': 'product_id',
#     'description': 'Identifier of the product purchased in this order line; foreign key referencing products.product_id.',
#     'datatype': 'object',
#     'sample_values': ['1913e11c70ce94032c05b17bbded599a',
#      'e469aee0b4bc4932389a283ab64b0860']},
#    {'column_name': 'seller_id',
#     'description': 'Identifier of the seller fulfilling this order line; foreign key referencing sellers.seller_id.',
#     'datatype': 'object',
#     'sample_values': ['2c3d56f92f360fb89d849b84e8f50eae',
#      'b4ffb71f0cb1b1c3d63fad021ecf93e1']},
#    {'column_name': 'shipping_limit_date',
#     'description': 'Deadline timestamp by which the seller should hand over the item to the logistics carrier/shipping service, typically used to measure seller handling time compliance.',
#     'datatype': 'object',
#     'sample_values': ['2018-01-30 10:16:19', '2018-02-20 11:55:33']},
#    {'column_name': 'price',
#     'description': 'Unit price charged for this order item line (excluding freight), expressed as a decimal monetary amount.',
#     'datatype': 'float64',
#     'sample_values': ['23.0', '10.0']},
#    {'column_name': 'freight_value',
#     'description': 'Freight/shipping cost attributed to this specific order item line, expressed as a decimal monetary amount.',
#     'datatype': 'float64',
#     'sample_values': ['22.22', '11.85']}]},
#  'order_payments': {'table_description': 'Stores payment transaction details for each order, including support for multiple payments per order (e.g., split across methods or transactions), the payment method used, installment count, and the monetary amount paid in each transaction.',
#   'columns': [{'column_name': 'order_id',
#     'description': 'Unique identifier of the order this payment record belongs to; acts as a foreign key to orders.order_id. Multiple rows may share the same order_id when an order is paid using multiple payment transactions.',
#     'datatype': 'object',
#     'sample_values': ['a402af38a74c44926247db438245d95c',
#      '1f667257ee2e5233698f7509dee81690']},
#    {'column_name': 'payment_sequential',
#     'description': 'Sequence number of the payment transaction within the same order_id, starting at 1. Used to distinguish multiple payment records for a single order when payments are split across methods or multiple transactions.',
#     'datatype': 'int64',
#     'sample_values': [1, 1]},
#    {'column_name': 'payment_type',
#     'description': 'Payment method used for this payment transaction (e.g., credit card). Indicates how the customer paid for this portion of the order total.',
#     'datatype': 'object',
#     'sample_values': ['credit_card', 'credit_card']},
#    {'column_name': 'payment_installments',
#     'description': 'Number of installments selected for this payment transaction. Typically applicable to installment-capable methods (e.g., credit card) and often equals 1 for single-payment transactions.',
#     'datatype': 'int64',
#     'sample_values': [5, 1]},
#    {'column_name': 'payment_value',
#     'description': 'Monetary amount paid in this specific payment transaction for the order, expressed as a decimal currency value. For orders with multiple payment records, the sum across records typically equals the total paid for the order.',
#     'datatype': 'float64',
#     'sample_values': [282.25, 70.65]}]},
#  'order_reviews': {'table_description': 'Stores customer-submitted reviews for completed orders, including the numeric rating, optional title/message text, and timestamps for when the review was created and when it received a response.',
#   'columns': [{'column_name': 'review_id',
#     'description': 'Unique identifier for each review record. Typically a hashed/UUID-like string used as the primary key to distinguish one review from another.',
#     'datatype': 'object',
#     'sample_values': ['78f48600d0d2c2e4c796ff731bbfbd29',
#      'faa8c3ccef5763059570f6e6bf0aaea8']},
#    {'column_name': 'order_id',
#     'description': 'Identifier of the order that the review refers to; acts as a foreign key linking the review to a specific purchase in the orders table.',
#     'datatype': 'object',
#     'sample_values': ['5ad7d897998f9bab0176a1c82b7437ea',
#      '79e0a33a60d364f1cf08bcd097985238']},
#    {'column_name': 'review_score',
#     'description': 'Numeric rating assigned by the customer for the order experience (e.g., commonly on a 1–5 scale), used for satisfaction/quality metrics.',
#     'datatype': 'int64',
#     'sample_values': ['5', '5']},
#    {'column_name': 'review_comment_title',
#     'description': 'Optional short title or summary text for the review. May be null when the customer only provides a score without a written title.',
#     'datatype': 'object',
#     'sample_values': [None, None]},
#    {'column_name': 'review_comment_message',
#     'description': 'Optional full review text message entered by the customer describing their experience. May be null when no written feedback is provided.',
#     'datatype': 'object',
#     'sample_values': [None, None]},
#    {'column_name': 'review_creation_date',
#     'description': 'Datetime (stored as a string) indicating when the customer created/submitted the review.',
#     'datatype': 'object',
#     'sample_values': ['2017-09-15 00:00:00', '2018-05-15 00:00:00']},
#    {'column_name': 'review_answer_timestamp',
#     'description': 'Datetime (stored as a string) indicating when the seller or platform posted a response to the review, if a response exists.',
#     'datatype': 'object',
#     'sample_values': ['2017-09-18 18:48:46', '2018-05-16 18:17:13']}]},
#  'products': {'table_description': 'Contains product-level master data, including category (in Brazilian Portuguese) and basic merchandising/packaging attributes such as text lengths, photo count, weight, and physical dimensions.',
#   'columns': [{'column_name': 'product_id',
#     'description': 'Unique identifier for each product record, represented as a hexadecimal-like string. Used as the primary key to join product attributes to other datasets (e.g., orders, listings, reviews).',
#     'datatype': 'object',
#     'sample_values': ['fe61253e50ad6ee9f1d180da22ce5eef',
#      'de04a994ad17964562eb95e322d13529']},
#    {'column_name': 'product_category_name',
#     'description': 'Product category label in Brazilian Portuguese, indicating the retail category the product belongs to (e.g., automotive, fashion accessories). Useful for grouping, filtering, and category-level analytics.',
#     'datatype': 'object',
#     'sample_values': ['automotivo', 'fashion_bolsas_e_acessorios']},
#    {'column_name': 'product_name_lenght',
#     'description': 'Length of the product name text in characters. Stored as a numeric value (float) though it represents a count; useful for text completeness/quality checks and catalog analysis.',
#     'datatype': 'float64',
#     'sample_values': ['54.0', '45.0']},
#    {'column_name': 'product_description_lenght',
#     'description': 'Length of the product description text in characters. Stored as a numeric value (float) though it represents a count; helps measure description richness and content completeness.',
#     'datatype': 'float64',
#     'sample_values': ['2711.0', '403.0']},
#    {'column_name': 'product_photos_qty',
#     'description': 'Number of photos available for the product listing. Stored as a numeric value (float) though it represents a count; used to assess listing quality and media completeness.',
#     'datatype': 'float64',
#     'sample_values': ['5.0', '3.0']},
#    {'column_name': 'product_weight_g',
#     'description': 'Product weight in grams, typically used for shipping calculations and logistics constraints. Stored as a numeric value (float).',
#     'datatype': 'float64',
#     'sample_values': ['1050.0', '150.0']},
#    {'column_name': 'product_length_cm',
#     'description': 'Product length in centimeters (packaged or measured dimension used for shipping/fulfillment). Stored as a numeric value (float).',
#     'datatype': 'float64',
#     'sample_values': ['18.0', '16.0']},
#    {'column_name': 'product_height_cm',
#     'description': 'Product height in centimeters (packaged or measured dimension used for shipping/fulfillment). Stored as a numeric value (float).',
#     'datatype': 'float64',
#     'sample_values': ['22.0', '9.0']},
#    {'column_name': 'product_width_cm',
#     'description': 'Product width in centimeters (packaged or measured dimension used for shipping/fulfillment). Stored as a numeric value (float).',
#     'datatype': 'float64',
#     'sample_values': ['20.0', '11.0']}]},
#  'product_category_translation': {'table_description': 'Lookup table that maps product category names from Brazilian Portuguese (original dataset labels) to their English translations for reporting, analytics, and normalization across languages.',
#   'columns': [{'column_name': 'product_category_name',
#     'description': 'Product category identifier/name in Brazilian Portuguese as used in the source catalog. Typically stored as a lowercase, underscore-separated slug (e.g., words joined by underscores) and serves as the key for translation to English.',
#     'datatype': 'object',
#     'sample_values': ['fashion_roupa_infanto_juvenil', 'moveis_quarto']},
#    {'column_name': 'product_category_name_english',
#     'description': 'English translation of the corresponding Brazilian Portuguese product category name. Typically stored as a lowercase, underscore-separated slug aligned to the Portuguese category key for consistent multilingual categorization.',
#     'datatype': 'object',
#     'sample_values': ['fashion_childrens_clothes', 'furniture_bedroom']}]},
#  'sellers': {'table_description': "Contains seller identification and location details, including the seller's postal code prefix, city, and state.",
#   'columns': [{'column_name': 'seller_id',
#     'description': 'Unique alphanumeric identifier assigned to each seller record; serves as the primary key to distinguish sellers and to join with other commerce/order datasets.',
#     'datatype': 'object',
#     'sample_values': ['1c56ffe0e9dea2657fc6e95b53f40b13',
#      'bc47d5d1490df2b36add65d733eafaba']},
#    {'column_name': 'seller_zip_code_prefix',
#     'description': "Numeric prefix of the seller's postal code representing the seller's general geographic area; used for regional grouping, distance estimates, and logistics analysis.",
#     'datatype': 'int64',
#     'sample_values': ['13575', '9163']},
#    {'column_name': 'seller_city',
#     'description': 'Name of the city where the seller is located, stored in lowercase text; useful for city-level aggregation and location-based reporting.',
#     'datatype': 'object',
#     'sample_values': ['sao carlos', 'santo andre']},
#    {'column_name': 'seller_state',
#     'description': "Two-letter state abbreviation indicating the seller's state/location within the country; commonly used for state-level regional analysis.",
#     'datatype': 'object',
#     'sample_values': ['SP', 'SP']}]}}

# %%
with open('kb.pkl', 'wb') as f:
    pickle.dump(kb_final, f)
